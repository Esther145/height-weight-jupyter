# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("insurance.csv")

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207773    30.663397     1.094918  13270.422265
# std      14.048858     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
plt.plot(data.age,data.charges)
plt.xlabel("age")
plt.ylabel("charges")
# Out:
# Text(0, 0.5, 'charges')

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   19    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
plt.scatter(data.age,data.charges,color='r')
plt.xlabel("age")
plt.ylabel("charges")
# Out:
# Text(0, 0.5, 'charges')

# %%
plt.bar(data.age,data.charges,color='y')
plt.xlabel("age")
plt.ylabel("charges")
# Out:
# Text(0, 0.5, 'charges')

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object
